# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
from matplotlib import pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/Images/lena256.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap = 'gray')
cv2_imshow(gimg1)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
M = cv2.getRotationMatrix2D((128,128), 45,1)
ourimg = cv2.warpAffine(gimg1, M, (256,256))
cv2_imshow(ourimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
print(M)
print(M.shape)
# Out:
# [[  0.70710678   0.70710678 -53.01933598]
#  [ -0.70710678   0.70710678 128.        ]]
# (2, 3)

# %%
M = np.float32([[1,0,100],[0,1,50]])
ourimg = cv2.warpAffine(gimg1, M, (256,256))
cv2_imshow(ourimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
M1 = np.float32([[1,0,-128],[0,1,-128]])
ourimg1 = cv2.warpAffine(gimg1, M1, (256,256))
cv2_imshow(ourimg1)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
M = cv2.getRotationMatrix2D((128,128), 45,1)
outimg3 = cv2.warpAffine(gimg1, M2, (256,256))
cv2_imshow(outimg3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
print(M2)
# Out:
# [[ 0.70710678 -0.70710678  0.        ]
#  [ 0.70710678  0.70710678  0.        ]]

# %%
M3 = cv2.getRotationMatrix2D((128,128), 45,1)
ourimg3= cv2.warpAffine(outimg2, M3, (256,256))
cv2_imshow(ourimg3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
N1 = np.vstack([M1, [0,0,1]])
N2 = np.vstack([M1, [0,0,1]])
N3 = np.vstack([M1, [0,0,1]])
print(N1)
# Out:
# [[   1.    0. -128.]
#  [   0.    1. -128.]
#  [   0.    0.    1.]]

# %%
N4 = np.dot(N3,N2)
N5 = np.dot(N4,N1)
print(N6)
N6 = np.vstack([N5, [0,0,1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1521722342.py in <cell line: 0>()
#       1 N4 = np.dot(N3,N2)
#       2 N5 = np.dot(N4,N1)
# ----> 3 print(N6)
#       4 N6 = np.vstack([N5, [0,0,1]])
#
# NameError: name 'N6' is not defined

# %%
outimg4 =cv2.warpAffine(gImg1, N5, (256,256))
cv2_imshow(outimg4 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1530403792.py in <cell line: 0>()
# ----> 1 outimg4 =cv2.warpAffine(gImg1, N5, (256,256))
#       2 cv2_imshow(outimg4 )
#
# NameError: name 'gImg1' is not defined
