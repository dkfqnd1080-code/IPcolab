# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
from matplotlib import pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/Images/abcdef.bmp')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap = 'gray')
cv2_imshow(gimg1)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
label_H = np.uint8(labels * 179 / np.max(labels))
cv2_imshow(label_H)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3609071066.py in <cell line: 0>()
# ----> 1 label_H = np.uint8(labels * 179 / np.max(labels))
#       2 cv2_imshow(label_H)
#
# NameError: name 'labels' is not defined

# %%
bank = 255*np.ones_like(label_H)
labelImg = cv2.merge((label_H, label_H, label_H))
labelImg = cv2.cvtColor(labelImg, cv2.COLOR_HSV2BGR)
labelImg[label_H ==0] = 0
cv2_imshow(labelImg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-108080251.py in <cell line: 0>()
# ----> 1 bank = 255*np.ones_like(label_H)
#       2 labelImg = cv2.merge((label_H, label_H, label_H))
#       3 labelImg = cv2.cvtColor(labelImg, cv2.COLOR_HSV2BGR)
#       4 cv2_imshow(labelImg)
#
# NameError: name 'label_H' is not defined

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/Images/milkdrop.bmp')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap = 'gray')
cv2_imshow(gimg1)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
ret, thresh = cv2.threshold(gimg1, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
contour , hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img = cv2.drawContours(img, contour, -1, (0,0,255), 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
