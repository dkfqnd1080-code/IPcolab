# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
from matplotlib import pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/Images/abcdef.bmp')
print(img.shape)
gimg2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gimg2, cmap = 'gray')
# Out:
# (256, 256, 3)

# %%
def saturattion(val):
 if val > 255:
  return 255
 elif val < 0:
  return 0
 else:
  return val

# %%
gPoint = np.zeros((gimg1.shape[0], gimg1.shape[1]), dtype=np.ubyte)

# %%
for h in range(gimg2.shape[0]):
  for w in range(gimg2.shape[1]):
    pointval = 255-np.int32(gimg2[h, w])
    gPoint[h, w] = saturattion(pointval)

plt.imshow(gPoint, cmap = 'gray')

# %%
th= 128

for h in range(gimg2.shape[0]):
  for w in range(gimg2.shape[1]):
 if glmg1[h,w] > th:
  gPoint[h, w] = 255
 else:
  gPoint[h, w] = 0

plt.imshow(gPoint, cmap = 'gray')

# %%
numofclip = 3
modVal = 256/numofclip

for h in range(gimg2.shape[0]):
  for w in range(gimg2.shape[1]):
    pointval = np.int32(gimg2[h, w]) %modVal
    gPoint[h,w] = saturattion(pointval * numofclip)

plt.imshow(gPoint, cmap = 'gray',vmin = 0, vmax=255)
