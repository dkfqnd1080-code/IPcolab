# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
from matplotlib import pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/Images/home3.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap = 'gray')
cv2_imshow(gimg1)
# Out:
# (600, 800, 3)
# <PIL.Image.Image image mode=L size=800x600>

# %%
img2 = img.copy()

# %%
edges = cv2.Canny(gimg1, 100, 200)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=800x600>

# %%
lines = cv2.HoughLinesP(edges, 1, np/180,200)

for line in lines:
  rho,theta =line[0]
  a = np.cos(theta)
  b = np.sin(theta)

  x1,y1 = rho*a, rho*b
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
